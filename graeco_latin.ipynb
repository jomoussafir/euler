# %%
from itertools import *  # We will be using itertools.permutations and itertools.product
import numpy as np
import pandas as pd
import string

# %%
def graeco_latin(n):
    
    """
    Returns all Graeco-Latin squares of order n for n prime
    """
    
    lower = string.ascii_lowercase
    upper = string.ascii_uppercase

    A = {}
    for r in np.arange(1,n):
        A[r] = np.zeros((n,n), dtype="int")
        for i in np.arange(n):
            for j in np.arange(n):
                A[r][i,j] = (i + r*j) % n

    A_row_check = {}
    for r in np.arange(1,n):
        A_row_check[r] = all([len(np.unique(l))==n for l in list(A[r])])            

    A_col_check = {}
    for r in np.arange(1,n):
        A_col_check[r] = all([len(np.unique(l))==n for l in list(A[r].T)])            

    A_check = {}
    for r in np.arange(1,n):
        A_check[r] = A_col_check[r] and A_row_check[r]
        
    GL = []
    GL_df = []
    for r in np.arange(1,n):
        if A_check[r]:
            for s in np.arange(1,n):
                if A_check[s]:
                    if not (s==r):
                        GL_tmp = np.empty((n,n), dtype="S2")
                        for i in np.arange(n):
                            for j in np.arange(n):
                                GL_tmp[i,j] = (upper[A[r][i,j]] + lower[A[s][i,j]])

                        if len(set(GL_tmp.flatten()))==(n*n):
                            GL.append(GL_tmp)
                            GL_tmp_df = pd.DataFrame(GL_tmp)
                            for c in np.arange(n):
                                GL_tmp_df.loc[:,c] = GL_tmp_df.loc[:,c].apply(lambda x:x.decode("utf-8"))
                            GL_df.append(GL_tmp_df)

    d = {}
    d["A"] = A
    d["GL"] = GL
    d["GL_df"] = GL_df
    
    return GL_df

# %%
[len(graeco_latin(i)) for i in np.arange(1, 20)]
# Out:
# [0, 0, 2, 0, 12, 0, 30, 0, 18, 0, 90, 0, 132, 0, 24, 0, 240, 0, 306]

# %%
n=7
gl = graeco_latin(n)
for i in np.arange(len(gl)):
    print("="*(4*n+1))
    print(gl[i])
# Out:
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Bc  Ce  Dg  Eb  Fd  Gf
# 1  Bb  Cd  Df  Ea  Fc  Ge  Ag
# 2  Cc  De  Eg  Fb  Gd  Af  Ba
# 3  Dd  Ef  Fa  Gc  Ae  Bg  Cb
# 4  Ee  Fg  Gb  Ad  Bf  Ca  Dc
# 5  Ff  Ga  Ac  Be  Cg  Db  Ed
# 6  Gg  Ab  Bd  Cf  Da  Ec  Fe
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Bd  Cg  Dc  Ef  Fb  Ge
# 1  Bb  Ce  Da  Ed  Fg  Gc  Af
# 2  Cc  Df  Eb  Fe  Ga  Ad  Bg
# 3  Dd  Eg  Fc  Gf  Ab  Be  Ca
# 4  Ee  Fa  Gd  Ag  Bc  Cf  Db
# 5  Ff  Gb  Ae  Ba  Cd  Dg  Ec
# 6  Gg  Ac  Bf  Cb  De  Ea  Fd
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Be  Cb  Df  Ec  Fg  Gd
# 1  Bb  Cf  Dc  Eg  Fd  Ga  Ae
# 2  Cc  Dg  Ed  Fa  Ge  Ab  Bf
# 3  Dd  Ea  Fe  Gb  Af  Bc  Cg
# 4  Ee  Fb  Gf  Ac  Bg  Cd  Da
# 5  Ff  Gc  Ag  Bd  Ca  De  Eb
# 6  Gg  Ad  Ba  Ce  Db  Ef  Fc
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Bf  Cd  Db  Eg  Fe  Gc
# 1  Bb  Cg  De  Ec  Fa  Gf  Ad
# 2  Cc  Da  Ef  Fd  Gb  Ag  Be
# 3  Dd  Eb  Fg  Ge  Ac  Ba  Cf
# 4  Ee  Fc  Ga  Af  Bd  Cb  Dg
# 5  Ff  Gd  Ab  Bg  Ce  Dc  Ea
# 6  Gg  Ae  Bc  Ca  Df  Ed  Fb
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Bg  Cf  De  Ed  Fc  Gb
# 1  Bb  Ca  Dg  Ef  Fe  Gd  Ac
# 2  Cc  Db  Ea  Fg  Gf  Ae  Bd
# 3  Dd  Ec  Fb  Ga  Ag  Bf  Ce
# 4  Ee  Fd  Gc  Ab  Ba  Cg  Df
# 5  Ff  Ge  Ad  Bc  Cb  Da  Eg
# 6  Gg  Af  Be  Cd  Dc  Eb  Fa
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Cb  Ec  Gd  Be  Df  Fg
# 1  Bb  Dc  Fd  Ae  Cf  Eg  Ga
# 2  Cc  Ed  Ge  Bf  Dg  Fa  Ab
# 3  Dd  Fe  Af  Cg  Ea  Gb  Bc
# 4  Ee  Gf  Bg  Da  Fb  Ac  Cd
# 5  Ff  Ag  Ca  Eb  Gc  Bd  De
# 6  Gg  Ba  Db  Fc  Ad  Ce  Ef
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Cd  Eg  Gc  Bf  Db  Fe
# 1  Bb  De  Fa  Ad  Cg  Ec  Gf
# 2  Cc  Ef  Gb  Be  Da  Fd  Ag
# 3  Dd  Fg  Ac  Cf  Eb  Ge  Ba
# 4  Ee  Ga  Bd  Dg  Fc  Af  Cb
# 5  Ff  Ab  Ce  Ea  Gd  Bg  Dc
# 6  Gg  Bc  Df  Fb  Ae  Ca  Ed
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Ce  Eb  Gf  Bc  Dg  Fd
# 1  Bb  Df  Fc  Ag  Cd  Ea  Ge
# 2  Cc  Eg  Gd  Ba  De  Fb  Af
# 3  Dd  Fa  Ae  Cb  Ef  Gc  Bg
# 4  Ee  Gb  Bf  Dc  Fg  Ad  Ca
# 5  Ff  Ac  Cg  Ed  Ga  Be  Db
# 6  Gg  Bd  Da  Fe  Ab  Cf  Ec
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Cf  Ed  Gb  Bg  De  Fc
# 1  Bb  Dg  Fe  Ac  Ca  Ef  Gd
# 2  Cc  Ea  Gf  Bd  Db  Fg  Ae
# 3  Dd  Fb  Ag  Ce  Ec  Ga  Bf
# 4  Ee  Gc  Ba  Df  Fd  Ab  Cg
# 5  Ff  Ad  Cb  Eg  Ge  Bc  Da
# 6  Gg  Be  Dc  Fa  Af  Cd  Eb
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Cg  Ef  Ge  Bd  Dc  Fb
# 1  Bb  Da  Fg  Af  Ce  Ed  Gc
# 2  Cc  Eb  Ga  Bg  Df  Fe  Ad
# 3  Dd  Fc  Ab  Ca  Eg  Gf  Be
# 4  Ee  Gd  Bc  Db  Fa  Ag  Cf
# 5  Ff  Ae  Cd  Ec  Gb  Ba  Dg
# 6  Gg  Bf  De  Fd  Ac  Cb  Ea
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Db  Gc  Cd  Fe  Bf  Eg
# 1  Bb  Ec  Ad  De  Gf  Cg  Fa
# 2  Cc  Fd  Be  Ef  Ag  Da  Gb
# 3  Dd  Ge  Cf  Fg  Ba  Eb  Ac
# 4  Ee  Af  Dg  Ga  Cb  Fc  Bd
# 5  Ff  Bg  Ea  Ab  Dc  Gd  Ce
# 6  Gg  Ca  Fb  Bc  Ed  Ae  Df
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Dc  Ge  Cg  Fb  Bd  Ef
# 1  Bb  Ed  Af  Da  Gc  Ce  Fg
# 2  Cc  Fe  Bg  Eb  Ad  Df  Ga
# 3  Dd  Gf  Ca  Fc  Be  Eg  Ab
# 4  Ee  Ag  Db  Gd  Cf  Fa  Bc
# 5  Ff  Ba  Ec  Ae  Dg  Gb  Cd
# 6  Gg  Cb  Fd  Bf  Ea  Ac  De
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  De  Gb  Cf  Fc  Bg  Ed
# 1  Bb  Ef  Ac  Dg  Gd  Ca  Fe
# 2  Cc  Fg  Bd  Ea  Ae  Db  Gf
# 3  Dd  Ga  Ce  Fb  Bf  Ec  Ag
# 4  Ee  Ab  Df  Gc  Cg  Fd  Ba
# 5  Ff  Bc  Eg  Ad  Da  Ge  Cb
# 6  Gg  Cd  Fa  Be  Eb  Af  Dc
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Df  Gd  Cb  Fg  Be  Ec
# 1  Bb  Eg  Ae  Dc  Ga  Cf  Fd
# 2  Cc  Fa  Bf  Ed  Ab  Dg  Ge
# 3  Dd  Gb  Cg  Fe  Bc  Ea  Af
# 4  Ee  Ac  Da  Gf  Cd  Fb  Bg
# 5  Ff  Bd  Eb  Ag  De  Gc  Ca
# 6  Gg  Ce  Fc  Ba  Ef  Ad  Db
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Dg  Gf  Ce  Fd  Bc  Eb
# 1  Bb  Ea  Ag  Df  Ge  Cd  Fc
# 2  Cc  Fb  Ba  Eg  Af  De  Gd
# 3  Dd  Gc  Cb  Fa  Bg  Ef  Ae
# 4  Ee  Ad  Dc  Gb  Ca  Fg  Bf
# 5  Ff  Be  Ed  Ac  Db  Ga  Cg
# 6  Gg  Cf  Fe  Bd  Ec  Ab  Da
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Eb  Bc  Fd  Ce  Gf  Dg
# 1  Bb  Fc  Cd  Ge  Df  Ag  Ea
# 2  Cc  Gd  De  Af  Eg  Ba  Fb
# 3  Dd  Ae  Ef  Bg  Fa  Cb  Gc
# 4  Ee  Bf  Fg  Ca  Gb  Dc  Ad
# 5  Ff  Cg  Ga  Db  Ac  Ed  Be
# 6  Gg  Da  Ab  Ec  Bd  Fe  Cf
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Ec  Be  Fg  Cb  Gd  Df
# 1  Bb  Fd  Cf  Ga  Dc  Ae  Eg
# 2  Cc  Ge  Dg  Ab  Ed  Bf  Fa
# 3  Dd  Af  Ea  Bc  Fe  Cg  Gb
# 4  Ee  Bg  Fb  Cd  Gf  Da  Ac
# 5  Ff  Ca  Gc  De  Ag  Eb  Bd
# 6  Gg  Db  Ad  Ef  Ba  Fc  Ce
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Ed  Bg  Fc  Cf  Gb  De
# 1  Bb  Fe  Ca  Gd  Dg  Ac  Ef
# 2  Cc  Gf  Db  Ae  Ea  Bd  Fg
# 3  Dd  Ag  Ec  Bf  Fb  Ce  Ga
# 4  Ee  Ba  Fd  Cg  Gc  Df  Ab
# 5  Ff  Cb  Ge  Da  Ad  Eg  Bc
# 6  Gg  Dc  Af  Eb  Be  Fa  Cd
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Ef  Bd  Fb  Cg  Ge  Dc
# 1  Bb  Fg  Ce  Gc  Da  Af  Ed
# 2  Cc  Ga  Df  Ad  Eb  Bg  Fe
# 3  Dd  Ab  Eg  Be  Fc  Ca  Gf
# 4  Ee  Bc  Fa  Cf  Gd  Db  Ag
# 5  Ff  Cd  Gb  Dg  Ae  Ec  Ba
# 6  Gg  De  Ac  Ea  Bf  Fd  Cb
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Eg  Bf  Fe  Cd  Gc  Db
# 1  Bb  Fa  Cg  Gf  De  Ad  Ec
# 2  Cc  Gb  Da  Ag  Ef  Be  Fd
# 3  Dd  Ac  Eb  Ba  Fg  Cf  Ge
# 4  Ee  Bd  Fc  Cb  Ga  Dg  Af
# 5  Ff  Ce  Gd  Dc  Ab  Ea  Bg
# 6  Gg  Df  Ae  Ed  Bc  Fb  Ca
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Fb  Dc  Bd  Ge  Ef  Cg
# 1  Bb  Gc  Ed  Ce  Af  Fg  Da
# 2  Cc  Ad  Fe  Df  Bg  Ga  Eb
# 3  Dd  Be  Gf  Eg  Ca  Ab  Fc
# 4  Ee  Cf  Ag  Fa  Db  Bc  Gd
# 5  Ff  Dg  Ba  Gb  Ec  Cd  Ae
# 6  Gg  Ea  Cb  Ac  Fd  De  Bf
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Fc  De  Bg  Gb  Ed  Cf
# 1  Bb  Gd  Ef  Ca  Ac  Fe  Dg
# 2  Cc  Ae  Fg  Db  Bd  Gf  Ea
# 3  Dd  Bf  Ga  Ec  Ce  Ag  Fb
# 4  Ee  Cg  Ab  Fd  Df  Ba  Gc
# 5  Ff  Da  Bc  Ge  Eg  Cb  Ad
# 6  Gg  Eb  Cd  Af  Fa  Dc  Be
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Fd  Dg  Bc  Gf  Eb  Ce
# 1  Bb  Ge  Ea  Cd  Ag  Fc  Df
# 2  Cc  Af  Fb  De  Ba  Gd  Eg
# 3  Dd  Bg  Gc  Ef  Cb  Ae  Fa
# 4  Ee  Ca  Ad  Fg  Dc  Bf  Gb
# 5  Ff  Db  Be  Ga  Ed  Cg  Ac
# 6  Gg  Ec  Cf  Ab  Fe  Da  Bd
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Fe  Db  Bf  Gc  Eg  Cd
# 1  Bb  Gf  Ec  Cg  Ad  Fa  De
# 2  Cc  Ag  Fd  Da  Be  Gb  Ef
# 3  Dd  Ba  Ge  Eb  Cf  Ac  Fg
# 4  Ee  Cb  Af  Fc  Dg  Bd  Ga
# 5  Ff  Dc  Bg  Gd  Ea  Ce  Ab
# 6  Gg  Ed  Ca  Ae  Fb  Df  Bc
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Fg  Df  Be  Gd  Ec  Cb
# 1  Bb  Ga  Eg  Cf  Ae  Fd  Dc
# 2  Cc  Ab  Fa  Dg  Bf  Ge  Ed
# 3  Dd  Bc  Gb  Ea  Cg  Af  Fe
# 4  Ee  Cd  Ac  Fb  Da  Bg  Gf
# 5  Ff  De  Bd  Gc  Eb  Ca  Ag
# 6  Gg  Ef  Ce  Ad  Fc  Db  Ba
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Gb  Fc  Ed  De  Cf  Bg
# 1  Bb  Ac  Gd  Fe  Ef  Dg  Ca
# 2  Cc  Bd  Ae  Gf  Fg  Ea  Db
# 3  Dd  Ce  Bf  Ag  Ga  Fb  Ec
# 4  Ee  Df  Cg  Ba  Ab  Gc  Fd
# 5  Ff  Eg  Da  Cb  Bc  Ad  Ge
# 6  Gg  Fa  Eb  Dc  Cd  Be  Af
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Gc  Fe  Eg  Db  Cd  Bf
# 1  Bb  Ad  Gf  Fa  Ec  De  Cg
# 2  Cc  Be  Ag  Gb  Fd  Ef  Da
# 3  Dd  Cf  Ba  Ac  Ge  Fg  Eb
# 4  Ee  Dg  Cb  Bd  Af  Ga  Fc
# 5  Ff  Ea  Dc  Ce  Bg  Ab  Gd
# 6  Gg  Fb  Ed  Df  Ca  Bc  Ae
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Gd  Fg  Ec  Df  Cb  Be
# 1  Bb  Ae  Ga  Fd  Eg  Dc  Cf
# 2  Cc  Bf  Ab  Ge  Fa  Ed  Dg
# 3  Dd  Cg  Bc  Af  Gb  Fe  Ea
# 4  Ee  Da  Cd  Bg  Ac  Gf  Fb
# 5  Ff  Eb  De  Ca  Bd  Ag  Gc
# 6  Gg  Fc  Ef  Db  Ce  Ba  Ad
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Ge  Fb  Ef  Dc  Cg  Bd
# 1  Bb  Af  Gc  Fg  Ed  Da  Ce
# 2  Cc  Bg  Ad  Ga  Fe  Eb  Df
# 3  Dd  Ca  Be  Ab  Gf  Fc  Eg
# 4  Ee  Db  Cf  Bc  Ag  Gd  Fa
# 5  Ff  Ec  Dg  Cd  Ba  Ae  Gb
# 6  Gg  Fd  Ea  De  Cb  Bf  Ac
# =============================
#     0   1   2   3   4   5   6
# 0  Aa  Gf  Fd  Eb  Dg  Ce  Bc
# 1  Bb  Ag  Ge  Fc  Ea  Df  Cd
# 2  Cc  Ba  Af  Gd  Fb  Eg  De
# 3  Dd  Cb  Bg  Ae  Gc  Fa  Ef
# 4  Ee  Dc  Ca  Bf  Ad  Gb  Fg
# 5  Ff  Ed  Db  Cg  Be  Ac  Ga
# 6  Gg  Fe  Ec  Da  Cf  Bd  Ab

# %%
# Out:
# 1.157920892373162e+77
